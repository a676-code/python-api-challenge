# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
import geoviews as gv

import json

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0       busselton -33.6500  115.3333    287.44        79          92
# 1        1  saint-philippe -21.3585   55.7679    296.92        82          30
# 2        2      georgetown   5.4112  100.3354    298.11        93          20
# 3        3     east london -33.0153   27.9116    292.92        69           0
# 4        4          barrow  71.2906 -156.7887    252.16        77         100
#
#    Wind Speed Country        Date
# 0        2.10      AU  1680729730
# 1        2.96      RE  1680729731
# 2        1.03      MY  1680729732
# 3        6.96      ZA  1680729432
# 4        4.63      US  1680729733

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
map_plot = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "EsriNatGeo",
    frame_width = 700,
    frame_height = 500,
    size = "Humidity",
    scale = 0.75,
    color = "City"
)

# Display the map
map_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
# converting temperatures to Celsius
city_data_df['Max Temp'] = city_data_df['Max Temp'] - 273.15

city_data_df = city_data_df[(city_data_df['Max Temp'] >= 20) & (city_data_df['Max Temp'] <= 29.5)]
city_data_df = city_data_df[city_data_df['Humidity'] <= 70]
city_data_df = city_data_df[(city_data_df['Cloudiness'] >= 5) & (city_data_df['Cloudiness'] <= 80)]

# Drop any rows with null values
dropped_city_data_df = city_data_df.dropna(how="any")

# Display sample data
dropped_city_data_df
# Out:
#      City_ID            City      Lat       Lng  Max Temp  Humidity  \
# 12        12         biloela -24.4167  150.5000     21.61        47
# 29        29       ewa beach  21.3156 -158.0072     27.97        60
# 67        67  cabo san lucas  22.8909 -109.9124     26.45        61
# 79        79       catamarca -28.4696  -65.7852     25.99        58
# 104      104         manaira  -7.7061  -38.1544     23.20        63
# 105      105       olavarria -36.8927  -60.3225     21.74        47
# 111      111       bathsheba  13.2167  -59.5167     28.34        65
# 116      116       thinadhoo   0.5333   72.9333     28.24        69
# 117      117      san andres  12.5847  -81.7006     29.01        70
# 133      133          calama -22.4667  -68.9333     22.27        21
# 172      172            mana   5.6592  -53.7767     26.51        70
# 174      174          ixtapa  20.7000 -105.2000     25.57        65
# 197      197          faanui -16.4833 -151.7500     28.07        69
# 211      211            vite  17.2833   74.5500     26.33        44
# 244      244         kahului  20.8947 -156.4700     28.01        60
# 259      259          lompoc  34.6391 -120.4579     20.01        58
# 262      262        ahuimanu  21.4447 -157.8378     27.84        68
# 270      270         hualmay -11.0964  -77.6139     27.35        70
# 275      275         shakawe -18.3667   21.8500     22.79        42
# 290      290            esna  25.2934   32.5540     22.01        17
# 292      292          vavoua   7.3819   -6.4778     26.83        63
# 296      296        san juan -31.5375  -68.5364     28.29        32
# 302      302   makakilo city  21.3469 -158.0858     27.18        61
# 327      327     nuevo ideal  24.8875 -105.0728     26.78         9
# 368      368    general pico -35.6566  -63.7568     26.62        38
# 425      425         champua  22.0833   85.6667     25.73        40
# 431      431          ocampo  21.6500 -101.5000     27.49         9
# 437      437       les cayes  18.2000  -73.7500     27.58        65
# 517      517           moron -34.6534  -58.6198     23.94        65
# 538      538            sale  34.0389   -6.8166     22.38        33
# 552      552           bajil  15.0584   43.2851     28.92        65
#
#      Cloudiness  Wind Speed Country        Date
# 12           11        1.81      AU  1680729737
# 29           40        8.75      US  1680729745
# 67           20        5.14      MX  1680729737
# 79           76        2.68      AR  1680729764
# 104          71        1.21      BR  1680729772
# 105          11        6.38      AR  1680729772
# 111          20        6.69      BB  1680729501
# 116          13        2.80      MV  1680729775
# 117          40        5.66      CO  1680729775
# 133          40        8.75      CL  1680729779
# 172          67        3.82      GF  1680729789
# 174          40        5.66      MX  1680729790
# 197          11        3.17      PF  1680729798
# 211           6        3.66      IN  1680729802
# 244          20       10.29      US  1680729809
# 259          75        8.23      US  1680729808
# 262          40        8.75      US  1680729814
# 270          35        4.62      PE  1680729815
# 275          44        2.11      BW  1680729817
# 290          45        4.95      EG  1680729821
# 292          42        1.83      CI  1680729822
# 296          79        2.57      AR  1680729586
# 302          40        8.75      US  1680729825
# 327          54        9.68      MX  1680729832
# 368          18        5.40      AR  1680729848
# 425           5        0.93      IN  1680729875
# 431          65        6.20      MX  1680729877
# 437          39        4.28      HT  1680729879
# 517          33        3.16      AR  1680729901
# 538          40        5.14      MA  1680729913
# 552          28        2.57      YE  1680729920

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = dropped_city_data_df[['City', 'Country', 'Lat', 'Lng', 'Humidity']]

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df['Hotel Name'] = ''

# Display sample data
hotel_df
# Out:
# C:\Users\aloun\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
#                City Country      Lat       Lng  Humidity Hotel Name
# 12          biloela      AU -24.4167  150.5000        47
# 29        ewa beach      US  21.3156 -158.0072        60
# 67   cabo san lucas      MX  22.8909 -109.9124        61
# 79        catamarca      AR -28.4696  -65.7852        58
# 104         manaira      BR  -7.7061  -38.1544        63
# 105       olavarria      AR -36.8927  -60.3225        47
# 111       bathsheba      BB  13.2167  -59.5167        65
# 116       thinadhoo      MV   0.5333   72.9333        69
# 117      san andres      CO  12.5847  -81.7006        70
# 133          calama      CL -22.4667  -68.9333        21
# 172            mana      GF   5.6592  -53.7767        70
# 174          ixtapa      MX  20.7000 -105.2000        65
# 197          faanui      PF -16.4833 -151.7500        69
# 211            vite      IN  17.2833   74.5500        44
# 244         kahului      US  20.8947 -156.4700        60
# 259          lompoc      US  34.6391 -120.4579        58
# 262        ahuimanu      US  21.4447 -157.8378        68
# 270         hualmay      PE -11.0964  -77.6139        70
# 275         shakawe      BW -18.3667   21.8500        42
# 290            esna      EG  25.2934   32.5540        17
# 292          vavoua      CI   7.3819   -6.4778        63
# 296        san juan      AR -31.5375  -68.5364        32
# 302   makakilo city      US  21.3469 -158.0858        61
# 327     nuevo ideal      MX  24.8875 -105.0728         9
# 368    general pico      AR -35.6566  -63.7568        38
# 425         champua      IN  22.0833   85.6667        40
# 431          ocampo      MX  21.6500 -101.5000         9
# 437       les cayes      HT  18.2000  -73.7500        65
# 517           moron      AR -34.6534  -58.6198        65
# 538            sale      MA  34.0389   -6.8166        33
# 552           bajil      YE  15.0584   43.2851        65

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
categories = "accommodation.hotel"
radius = 10000
params = {
    "categories":categories,
    "radius":radius,
    "apiKey":geoapify_key
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lat = row['Lat']
    lon = row['Lng']
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{lon},{lat},{radius}"
    params["bias"] = f"proximity:{lon},{lat}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"
    
    
    # Make and API request using the params dictionary
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # print(json.dumps(name_address, indent=4, sort_keys=True))
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError) as e:
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# C:\Users\aloun\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# biloela - nearest hotel: No hotel found
# ewa beach - nearest hotel: Hampton Inn & Suites Oahu/Kapolei
# cabo san lucas - nearest hotel: Comfort Rooms
# catamarca - nearest hotel: Hotel de Turismo
# manaira - nearest hotel: No hotel found
# olavarria - nearest hotel: Santa Rosa Hotel
# bathsheba - nearest hotel: Atlantis Hotel
# thinadhoo - nearest hotel: No hotel found
# san andres - nearest hotel: Hotel Decameron Isleño
# calama - nearest hotel: Apart Hotel Geotel Calama
# mana - nearest hotel: Le Samana
# ixtapa - nearest hotel: Ma. Cristina
# faanui - nearest hotel: Oa Oa Lodge
# vite - nearest hotel: No hotel found
# kahului - nearest hotel: Maui Seaside Hotel
# lompoc - nearest hotel: Embassy Suites by Hilton Lompoc Central Coast
# ahuimanu - nearest hotel: No hotel found
# hualmay - nearest hotel: Hotel Mi Choacan
# shakawe - nearest hotel: Drotsky's Cabins
# esna - nearest hotel: No hotel found
# vavoua - nearest hotel: Hôtel Sougoun
# san juan - nearest hotel: Hotel San Francisco
# makakilo city - nearest hotel: Embassy Suites by Hilton Oahu Kapolei
# nuevo ideal - nearest hotel: No hotel found
# general pico - nearest hotel: Euskadi Hotel
# champua - nearest hotel: No hotel found
# ocampo - nearest hotel: No hotel found
# les cayes - nearest hotel: No hotel found
# moron - nearest hotel: La Esquina
# sale - nearest hotel: Le dawliz
# bajil - nearest hotel: فندق و أجنحة الشرق الأوسط
#                City Country      Lat       Lng  Humidity  \
# 12          biloela      AU -24.4167  150.5000        47
# 29        ewa beach      US  21.3156 -158.0072        60
# 67   cabo san lucas      MX  22.8909 -109.9124        61
# 79        catamarca      AR -28.4696  -65.7852        58
# 104         manaira      BR  -7.7061  -38.1544        63
# 105       olavarria      AR -36.8927  -60.3225        47
# 111       bathsheba      BB  13.2167  -59.5167        65
# 116       thinadhoo      MV   0.5333   72.9333        69
# 117      san andres      CO  12.5847  -81.7006        70
# 133          calama      CL -22.4667  -68.9333        21
# 172            mana      GF   5.6592  -53.7767        70
# 174          ixtapa      MX  20.7000 -105.2000        65
# 197          faanui      PF -16.4833 -151.7500        69
# 211            vite      IN  17.2833   74.5500        44
# 244         kahului      US  20.8947 -156.4700        60
# 259          lompoc      US  34.6391 -120.4579        58
# 262        ahuimanu      US  21.4447 -157.8378        68
# 270         hualmay      PE -11.0964  -77.6139        70
# 275         shakawe      BW -18.3667   21.8500        42
# 290            esna      EG  25.2934   32.5540        17
# 292          vavoua      CI   7.3819   -6.4778        63
# 296        san juan      AR -31.5375  -68.5364        32
# 302   makakilo city      US  21.3469 -158.0858        61
# 327     nuevo ideal      MX  24.8875 -105.0728         9
# 368    general pico      AR -35.6566  -63.7568        38
# 425         champua      IN  22.0833   85.6667        40
# 431          ocampo      MX  21.6500 -101.5000         9
# 437       les cayes      HT  18.2000  -73.7500        65
# 517           moron      AR -34.6534  -58.6198        65
# 538            sale      MA  34.0389   -6.8166        33
# 552           bajil      YE  15.0584   43.2851        65
#
#                                         Hotel Name
# 12                                  No hotel found
# 29               Hampton Inn & Suites Oahu/Kapolei
# 67                                   Comfort Rooms
# 79                                Hotel de Turismo
# 104                                 No hotel found
# 105                               Santa Rosa Hotel
# 111                                 Atlantis Hotel
# 116                                 No hotel found
# 117                         Hotel Decameron Isleño
# 133                      Apart Hotel Geotel Calama
# 172                                      Le Samana
# 174                                   Ma. Cristina
# 197                                    Oa Oa Lodge
# 211                                 No hotel found
# 244                             Maui Seaside Hotel
# 259  Embassy Suites by Hilton Lompoc Central Coast
# 262                                 No hotel found
# 270                               Hotel Mi Choacan
# 275                               Drotsky's Cabins
# 290                                 No hotel found
# 292                                  Hôtel Sougoun
# 296                            Hotel San Francisco
# 302          Embassy Suites by Hilton Oahu Kapolei
# 327                                 No hotel found
# 368                                  Euskadi Hotel
# 425                                 No hotel found
# 431                                 No hotel found
# 437                                 No hotel found
# 517                                     La Esquina
# 538                                      Le dawliz
# 552                      فندق و أجنحة الشرق الأوسط

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
map_plot = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "EsriNatGeo",
    frame_width = 700,
    frame_height = 500,
    size = "Humidity",
    scale = 1,
    color = "City",
    hover_cols = ['Hotel Name', 'Country']
)

# Display the map
map_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
